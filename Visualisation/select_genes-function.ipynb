# %%
import pandas as pd
import os
from glob import glob

# %%
# Please note the this script ONLY work if the phage-genome-analysis-pipeline snakefile was used before
# Please enter to path to the result, This path should be the same as the analysis_folder_path in phage-genome-analysis-pipeline snakefile 
phold_result_path = "/home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/"

# %%
# Create a list to stock all the dataframe
dataframes = []

# Iterating throught all the "phold_per_cds_predictions.tsv" file. There should be one file per sample 
# (one of those file is created in each phold analysis)
for file_path in glob(os.path.join(phold_result_path, "*/Phold/phold_per_cds_predictions.tsv")):
    QC: print(file_path)

    # Thean each of the tsv file is converted into a pandas dataframe
    df = pd.read_csv(file_path, delimiter='\t')
    
    # Only the needed columns are selected
    selected_columns = df[['cds_id','function']] 

    # QC: print(selected_columns)
    # Those columns are added to the list previoulsy created
    dataframes.append(selected_columns)

# Concatenating all the dataframe (2 columns only)
final_df = pd.concat(dataframes)

# the dataframe is exported in a csv file78
final_df.to_csv("merged_cds_predictions.csv", index=False, sep=',')
# Out:
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/BW1B_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/9B_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/ST001-ECM1_3/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/Escherichia_phage_vB_EcoM-Ro121lw/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/10_EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/8B-EC78_1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/8B-EC78_2/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/ST001-ECM1_2/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/Escherichia_phage_ESCO13/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/8A-EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/OFV4_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/Salmonella_phage_emhyr/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SW3C-EC78_1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/OFV4-ECM1_1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/Escherichia_phage_PNJ1809-36/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/7_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/8D1-EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/W2_EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SW3BEC178/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SS3-ECM1_1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SW3C-EC78_2/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/9_EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/Escherichia_phage_vB_EcoP_ZX5/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/8B-ECM1_2/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SW3A_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/Serratia_phage_vB_SmaP-Kaonashi/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/7B_EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/8B-ECM1_1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/ST002_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/7_EC78/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SS3-ECM1_2/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/SW33_ECM1/Phold/phold_per_cds_predictions.tsv
# /home/champa/BIOINFO_Linux/PHAGE_genome_analysis/Denault_N/Chenard_result/ST001-ECM1_1/Phold/phold_per_cds_predictions.tsv

# %%
# A hexadecimal code of a colour is attribute to every function found by phold 
function_to_color = {
    'head and packaging': '#900c3f',
    'unknown function': '#fb4fd9',
    'connector':'#8f2be7',
    'tail': '#007bd8',
    'lysis': '#00e1da',
    'other':'#1fb819',
    'DNA, RNA and nucleotide metabolism': '#ffdb28',
    'moron, auxiliary metabolic gene and host takeover': '#f28200',
    'integration and excision':'#e9162d',
    'transcription regulation':'#ff6361'

}

# Extracting unique functions and their associated colors
unique_functions = final_df['function'].unique()
#If a function doesn't have an attribute colour, the arow will be black
color_mapping = [(func, function_to_color.get(func, '#000000')) for func in unique_functions]

# Create a DataFrame for the function-to-color mapping
color_df = pd.DataFrame(color_mapping, columns=['function', 'color'])

# Exporting a csv file with the fonction and the colours
color_df.to_csv("function_color_mapping.csv", index=False, sep=',')
